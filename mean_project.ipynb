# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
dataset = pd.read_csv(r"C:\Users\MRINALIN PANIGRAHI\OneDrive\ROHNIT coding\data science\dataset\apple_global_sales_dataset.csv")

# %%
dataset.head(10)
# Out:
#          sale_id   sale_date  year quarter    month    country         region  \
# 0  APPL-00000001  2022-01-03  2022      Q1  January  Argentina  South America
# 1  APPL-00000002  2022-01-04  2022      Q1  January  Argentina  South America
# 2  APPL-00000003  2022-05-18  2022      Q2      May  Argentina  South America
# 3  APPL-00000004  2022-05-23  2022      Q2      May  Argentina  South America
# 4  APPL-00000005  2022-07-13  2022      Q3     July  Argentina  South America
# 5  APPL-00000006  2022-07-31  2022      Q3     July  Argentina  South America
# 6  APPL-00000007  2022-08-01  2022      Q3   August  Argentina  South America
# 7  APPL-00000008  2022-08-04  2022      Q3   August  Argentina  South America
# 8  APPL-00000009  2023-01-14  2023      Q1  January  Argentina  South America
# 9  APPL-00000010  2023-01-26  2023      Q1  January  Argentina  South America
#
#            city              product_name     category  ... currency  \
# ...

# %%
dataset.head(5)["revenue_local_currency"].mean()
np.mean(dataset.head(5)["revenue_local_currency"])
dataset["revenue_local_currency"].head(5).mean()
# Out:
# np.float64(1355021.72)

# %%
np.mean(dataset.head(5)["revenue_local_currency"])
# Out:
# np.float64(1355021.72)

# %%
dataset["revenue_local_currency"].head(5).mean()
# Out:
# np.float64(1355021.72)

# %%
dataset.isnull().sum()
# Out:
# sale_id                      0
# sale_date                    0
# year                         0
# quarter                      0
# month                        0
# country                      0
# region                       0
# city                         0
# product_name                 0
# category                     0
# storage                   4804
# color                        0
# unit_price_usd               0
# discount_pct                 0
# units_sold                   0
# discounted_price_usd         0
# revenue_usd                  0
# currency                     0
# fx_rate_to_usd               0
# revenue_local_currency       0
# sales_channel                0
# payment_method               0
# customer_segment             0
# customer_age_group           0
# previous_device_os        8056
# customer_rating           3360
# return_status                0
# dtype: int64

# %%
dataset["fx_rate_to_usd"].mean()
# Out:
# np.float64(1029.4066469565219)

# %%
np.mean(dataset["fx_rate_to_usd"])
# Out:
# np.float64(1029.4066469565219)

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sale_id                 11500 non-null  str
#  1   sale_date               11500 non-null  str
#  2   year                    11500 non-null  int64
#  3   quarter                 11500 non-null  str
#  4   month                   11500 non-null  str
#  5   country                 11500 non-null  str
#  6   region                  11500 non-null  str
#  7   city                    11500 non-null  str
#  8   product_name            11500 non-null  str
#  9   category                11500 non-null  str
#  10  storage                 6696 non-null   str
#  11  color                   11500 non-null  str
#  12  unit_price_usd          11500 non-null  float64
#  13  discount_pct            11500 non-null  int64
#  14  units_sold              11500 non-null  int64
# ...

# %%
corrdata1=dataset.select_dtypes("float64","int64").corr()
corrdata1
# Out:
#                         unit_price_usd  discounted_price_usd  revenue_usd  \
# unit_price_usd                1.000000              0.998301     0.755070
# discounted_price_usd          0.998301              1.000000     0.757582
# revenue_usd                   0.755070              0.757582     1.000000
# fx_rate_to_usd               -0.010482             -0.009426    -0.012978
# revenue_local_currency        0.133406              0.135874     0.139827
# customer_rating               0.001737              0.000556     0.001323
#
#                         fx_rate_to_usd  revenue_local_currency  \
# unit_price_usd               -0.010482                0.133406
# discounted_price_usd         -0.009426                0.135874
# revenue_usd                  -0.012978                0.139827
# fx_rate_to_usd                1.000000                0.583349
# revenue_local_currency        0.583349                1.000000
# customer_rating              -0.004375               -0.002432
#
# ...

# %%
corrdata=dataset[["unit_price_usd","discounted_price_usd"]].corr()
corrdata
# Out:
#                       unit_price_usd  discounted_price_usd
# unit_price_usd              1.000000              0.998301
# discounted_price_usd        0.998301              1.000000

# %%
plt.figure(figsize=(5,3))
sns.heatmap(corrdata1,annot=True,fmt="0.4f",vmax=1,vmin=-0.25,cmap="coolwarm",
            linecolor="black",cbar=True,
            xticklabels=True, yticklabels=True,
            linewidths=0.6,
            )
plt.show()

# %%
dataset.isnull().sum()
# Out:
# sale_id                      0
# sale_date                    0
# year                         0
# quarter                      0
# month                        0
# country                      0
# region                       0
# city                         0
# product_name                 0
# category                     0
# storage                   4804
# color                        0
# unit_price_usd               0
# discount_pct                 0
# units_sold                   0
# discounted_price_usd         0
# revenue_usd                  0
# currency                     0
# fx_rate_to_usd               0
# revenue_local_currency       0
# sales_channel                0
# payment_method               0
# customer_segment             0
# customer_age_group           0
# previous_device_os        8056
# customer_rating           3360
# return_status                0
# dtype: int64
