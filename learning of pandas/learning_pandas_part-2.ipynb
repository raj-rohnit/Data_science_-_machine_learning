# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **groupby**

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
# Group by Category and calculate the sum of Sales
cat = df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
cat = df.groupby(['Category','Store'])['Sales'].sum()
cat
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [markdown]
# **Aggregation**

# %%
df['Sales'].mean()
# Out:
# np.float64(187.5)

# %%
df['Sales'].agg(['sum', 'mean', 'min', 'max', 'count', 'std', 'median'])
# Out:
# sum       1500.000000
# mean       187.500000
# min        100.000000
# max        300.000000
# count        8.000000
# std         66.062741
# median     190.000000
# Name: Sales, dtype: float64

# %% [markdown]
# **pivottables**

# %%
data2 = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
            'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df2 = pd.DataFrame(data2)
df2
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    777     87   John
# 1  2023-01-02       B   West    801     10   Mary
# 2  2023-01-03       C  North    380     95    Bob
# 3  2023-01-04       D  South    385     96  Alice
# 4  2023-01-05       A   East    327     28   John
# 5  2023-01-06       B   West    259     83   Mary
# 6  2023-01-07       C  North    272     30    Bob
# 7  2023-01-08       D  South    475     13  Alice
# 8  2023-01-09       A   East    750     75   John
# 9  2023-01-10       B   West    226     18   Mary
# 10 2023-01-11       C  North    804     41    Bob
# 11 2023-01-12       D  South    992     97  Alice
# 12 2023-01-13       A   East    154     21   John
# 13 2023-01-14       B   West    600     38   Mary
# 14 2023-01-15       C  North    861     47    Bob
# 15 2023-01-16       D  South    146     88  Alice
# 16 2023-01-17       A   East    263     79   John
# 17 2023-01-18       B   West    432     56   Mary
# 18 2023-01-19       C  North    561     25    Bob
# 19 2023-01-20       D  South    669     89  Alice
