# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **Pivot Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
            'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    701     67   John  January      Q1
# 1  2023-01-02       B   West    452     80   Mary  January      Q1
# 2  2023-01-03       C  North    953     24    Bob  January      Q1
# 3  2023-01-04       D  South    373     85  Alice  January      Q1
# 4  2023-01-05       A   East    452     82   John  January      Q1
# 5  2023-01-06       B   West    304     94   Mary  January      Q1
# 6  2023-01-07       C  North    314     87    Bob  January      Q1
# 7  2023-01-08       D  South    450     36  Alice  January      Q1
# 8  2023-01-09       A   East    178     48   John  January      Q1
# 9  2023-01-10       B   West    693     54   Mary  January      Q1
# 10 2023-01-11       C  North    475     78    Bob  January      Q1
# 11 2023-01-12       D  South    904     69  Alice  January      Q1
# 12 2023-01-13       A   East    888     27   John  January      Q1
# 13 2023-01-14       B   West    504     71   Mary  January      Q1
# 14 2023-01-15       C  North    390     46    Bob  January      Q1
# 15 2023-01-16       D  South    457     31  Alice  January      Q1
# 16 2023-01-17       A   East    761     97   John  January      Q1
# 17 2023-01-18       B   West    709     34   Mary  January      Q1
# 18 2023-01-19       C  North    982     14    Bob  January      Q1
# 19 2023-01-20       D  South    135     84  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     701.0    NaN    NaN    NaN
# North      NaN    NaN  475.0    NaN
# South      NaN    NaN    NaN  450.0
# West       NaN  504.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     596.0    NaN    NaN    NaN  64.2   NaN   NaN   NaN
# North      NaN    NaN  622.8    NaN   NaN   NaN  49.8   NaN
# South      NaN    NaN    NaN  463.8   NaN   NaN   NaN  61.0
# West       NaN  532.4    NaN    NaN   NaN  66.6   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
